# %% [markdown]
# <a href="https://colab.research.google.com/github/roshani1505/APS-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# -------------------------------
# 1. Modify program for user input graph using dictionary.
# -------------------------------
graph = {}
n = int(input("Enter number of vertices: "))

for i in range(n):
    node = input(f"Enter name of vertex {i+1}: ")
    graph[node] = {}

m = int(input("Enter number of edges: "))
for i in range(m):
    u = input(f"Edge {i+1} - from: ")
    v = input(f"Edge {i+1} - to: ")
    w = int(input(f"Edge {i+1} - weight: "))
    graph[u][v] = w
    graph[v][u] = w   # if undirected graph

start = input("Enter starting vertex: ")

# -------------------------------
# 2. Display shortest path with total distance.
# -------------------------------
result = dijkstra(graph, start)

for node in result:
    print(f"Distance from {start} to {node} = {result[node]}")

# -------------------------------
# 3. Add two more nodes in graph.
# -------------------------------
Two_more_nodes = 2
for i in range(Two_more_nodes):
    node = input(f"Enter name of vertex {i+1}: ")
    graph[node] = {}

more_edges = int(input("Enter number of edges: "))
for i in range(more_edges):
    u = input(f"Edge {i+1} - from: ")
    v = input(f"Edge {i+1} - to: ")
    w = int(input(f"Edge {i+1} - weight: "))
    graph[u][v] = w
    graph[v][u] = w   # if undirected graph

result = dijkstra(graph, start)

for node in result:
    print(f"Distance from {start} to {node} = {result[node]}")

# -------------------------------
# 4. Test algorithm with different source nodes.
# -------------------------------
new_start = input("Enter new starting vertex: ")
result = dijkstra(graph, new_start)

for node in result:
    print(f"Distance from {start} to {node} = {result[node]}")
# Out:
# Enter number of vertices: 5
# Enter name of vertex 1: A
# Enter name of vertex 2: B
# Enter name of vertex 3: C
# Enter name of vertex 4: D
# Enter name of vertex 5: E
# Enter number of edges: 6
# Edge 1 - from: A
# Edge 1 - to: B
# Edge 1 - weight: 3
# Edge 2 - from: A
# Edge 2 - to: E
# Edge 2 - weight: 4
# Edge 3 - from: A
# Edge 3 - to: D
# Edge 3 - weight: 1
# Edge 4 - from: B
# Edge 4 - to: C
# Edge 4 - weight: 9
# Edge 5 - from: D
# Edge 5 - to: C
# Edge 5 - weight: 7
# Edge 6 - from: E
# Edge 6 - to: B
# Edge 6 - weight: 6
# Enter starting vertex: A
# Distance from A to A = 0
# Distance from A to B = 3
# Distance from A to C = 8
# Distance from A to D = 1
# Distance from A to E = 4
# Enter name of vertex 1: F
# Enter name of vertex 2: G
# Enter number of edges: 4
# Edge 1 - from: B
# Edge 1 - to: G
# Edge 1 - weight: 8
# Edge 2 - from: C
# Edge 2 - to: G
# Edge 2 - weight: 2
# Edge 3 - from: G
# Edge 3 - to: F
# Edge 3 - weight: 4
# Edge 4 - from: B
# Edge 4 - to: F
# Edge 4 - weight: 10
# Distance from A to A = 0
# Distance from A to B = 3
# Distance from A to C = 8
# Distance from A to D = 1
# Distance from A to E = 4
# Distance from A to F = 13
# Distance from A to G = 10
# Enter new starting vertex: E
# Distance from A to A = 4
# Distance from A to B = 6
# Distance from A to C = 12
# Distance from A to D = 5
# Distance from A to E = 0
# Distance from A to F = 16
# Distance from A to G = 14
