# %% [markdown]
# <a href="https://colab.research.google.com/github/roshani1505/APS-Lab/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
#-------------------------
# 1. Print path of cities visited
#-------------------------
def tsp_path(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    path = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')
        best_next = -1

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost
                    best_next = next_city

        dp[city][mask] = ans
        path[city][mask] = best_next
        return ans

    # Run DP
    min_cost = visit(0, 1)

    # Reconstruct path
    mask = 1
    city = 0
    tour = [0]
    while True:
        next_city = path[city][mask]
        if next_city == -1:
            break
        tour.append(next_city)
        mask |= (1<<next_city)
        city = next_city
    tour.append(0)  # return to start

    return min_cost, tour

#-------------------------
# 2. Take graph input from user
#-------------------------
graph = []
n = int(input("Enter number of cities: "))
for i in range(n):
    row = []
    for j in range(n):
        row.append(int(input(f"Enter distance from city {i} to city {j}: ")))
    graph.append(row)

min_cost, tour = tsp_path(graph)
print("Minimum travelling cost:", min_cost)
print("Tour:", tour)

#-------------------------
# 3. Test with different number of cities
#-------------------------
graph = [
    [0, 10, 15, 5],
    [10, 0, 5, 25],
    [15, 40, 0, 30],
    [10, 25, 5, 0]
]
min_cost, tour = tsp_path(graph)
print("Minimum travelling cost for different number of cities:", min_cost)
print("Tour:", tour)
# Out:
# Enter number of cities: 4
# Enter distance from city 0 to city 0: 0
# Enter distance from city 0 to city 1: 7
# Enter distance from city 0 to city 2: 5
# Enter distance from city 0 to city 3: 9
# Enter distance from city 1 to city 0: 3
# Enter distance from city 1 to city 1: 0
# Enter distance from city 1 to city 2: 12
# Enter distance from city 1 to city 3: 4
# Enter distance from city 2 to city 0: 6
# Enter distance from city 2 to city 1: 10
# Enter distance from city 2 to city 2: 0
# Enter distance from city 2 to city 3: 5
# Enter distance from city 3 to city 0: 1
# Enter distance from city 3 to city 1: 10
# Enter distance from city 3 to city 2: 7
# Enter distance from city 3 to city 3: 6
# Minimum travelling cost: 20
# Tour: [0, 2, 1, 3, 0]
# Minimum travelling cost for different number of cities: 50
# Tour: [0, 3, 1, 2, 0]
